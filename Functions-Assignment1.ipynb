# %%
# Create a class and function, and list out the items in the list

# %%
def SubFields():
    subfieldsAI=["Manchine Learning","Neural Networks","Vision","Robotics","Speech Processing","Natural Language Processing"]
    for temp in subfieldsAI:
        print(temp)

# %%
SubFields()
# Out:
# Manchine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
 # Create a function that checks whether the given number is Odd or Even

# %%
def OddEven():
    num=int(input("Enter a number:"))
    if(num%2==0):
        print(num,"is Even Numer")
    else:
        print(num,"is Odd Numer")

# %%
OddEven()
# Out:
# Enter a number: 52452
# 52452 is Even Numer

# %%
# Create a function that tells elegibility of marriage for male and female according to their age limit like 21 for male and 18 for female

# %%
def ElegibilityForMarriage():
    gender=input("Enter your Gender:")
    age=int(input("Enter your Age:"))
    if(gender=='Male' and age>=21):
        print("Your Gender is:",gender)
        print("Your age is:",age)
        print("Eligible")
    elif(gender=='Female' and age>=18):
        print("Your Gender is:",gender)
        print("Your age is:",age)
        print("Eligible")
    else:
        print("Your Gender is:",gender)
        print("Your age is:",age)
        print("Not Eligible")

# %%
ElegibilityForMarriage()
# Out:
# Enter your Gender: female
# Enter your Age: 12
# Your Gender is: female
# Your age is: 12
# Not Eligible

# %%
ElegibilityForMarriage()
# Out:
# Enter your Gender: Male
# Enter your Age: 22
# Your Gender is: Male
# Your age is: 22
# Eligible

# %%
ElegibilityForMarriage()
# Out:
# Enter your Gender: Female
# Enter your Age: 20
# Your Gender is: Female
# Your age is: 20
# Eligible

# %%
ElegibilityForMarriage()
# Out:
# Enter your Gender: male
# Enter your Age: 19
# Your Gender is: male
# Your age is: 19
# Not Eligible

# %%
 # calculate the percentage of your 10th mark

# %%
def FindPercentage():
    sub1=int(input("Subject 1:"))
    sub2=int(input("Subject 2:"))
    sub3=int(input("Subject 3:"))
    sub4=int(input("Subject 4:"))
    sub5=int(input("Subject 5:"))
    total=sub1+sub2+sub3+sub4+sub5
    Percentage=total/5
    print("Subject1=",sub1)
    print("Subject12=",sub2)
    print("Subject3=",sub3)
    print("Subject4=",sub4)
    print("Subject5=",sub5)
    print("Total=",total)
    print("Percentage",Percentage)

# %%
FindPercentage()
# Out:
# Subject 1: 98
# Subject 2: 87
# Subject 3: 95
# Subject 4: 93
# Subject 5: 95
# Subject1= 98
# Subject12= 87
# Subject3= 95
# Subject4= 93
# Subject5= 95
# Total= 468
# Percentage 93.6

# %%
#print area and perimeter of triangle using class and functions

# %%
def triangle(height,breath):
    area=(height*breath)/2
    perimeter=height+height+breath
    print("Area of the Triangle is:",area)
    print("Perimeter of the Trianlge:",perimeter)

# %%
triangle(32,34)
# Out:
# Area of the Triangle is: 544.0
# Perimeter of the Trianlge: 98

# %%
def triangle(height,breath):
    area=(height*breath)/2
  
    print("Area of the Triangle is:",area)

def triangle1(height1,height2,breath):    
    perimeter=height1+height2+breath    
    print("Perimeter of the Trianlge:",perimeter)

# %%
triangle(32,34)
triangle1(2,4,4)
# Out:
# Area of the Triangle is: 544.0
# Perimeter of the Trianlge: 10
