# %%
from oddeven import OddEven

# %%
OddEven.oddEven()
# Out:
# Enter a number:  45
# 45 is Odd number

# %%
from oddeven import OddEven 
OddEven.oddEven()
# Out:
# Enter a number:  20
# 20 is Even number

# %%
from FieldsAI import subFieldsInAI
print ("Sub-Fileds in AI are:")

subFieldsInAI.subfields()
# Out:
# Sub-Fileds in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
from eligible import EligibilityForMarriage

EligibilityForMarriage.Eligible()
# Out:
# Enter your Gender: male
# Enter your age: 20
# Your Gender: male
# Your Age: 20
# Not Eligible

# %%
from eligible import EligibilityForMarriage

EligibilityForMarriage.Eligible()
# Out:
# Enter your Gender: female
# Enter your age: 17
# Your Gender: female
# Your Age: 17
# Not Eligible

# %%
from Percentage import calculatePercentage
calculatePercentage.FindPercentage()
# Out:
# Subject 1: 98
# Subject 2: 93
# Subject 3: 99
# Subject 4: 89
# Subject 5: 99
# Subject1 = 98
# Subject2 = 93
# Subject3 = 99
# Subject4 = 89
# Subject5 = 99
# Total = 478
# Percentage = 95.6

# %%
from Triangle import Triangle
Triangle.triangle(32,34)
Triangle.triangle1(2,4,4)
# Out:
# Area of the Triangle is: 544.0
# Perimeter of the Trianlge: 10
