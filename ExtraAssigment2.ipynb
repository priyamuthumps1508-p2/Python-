# %%
#print 'CORRECT' if i==0

# %%
value=int(input("Enter your input"))
i=value
if(i==10):
        print("Value:" ,i)
        print("Correct")
# Out:
# Enter your input 10
# Value: 10
# Correct

# %%
#check the password,using if and else

# %%
pwd=input("Enter your password")
if(pwd=='HOPE@123'):
    print("your password id correct")
else:
    print("Incorrect Passowrd")
# Out:
# Enter your password HOPE@123
# your password id correct

# %%
pwd=input("Enter your password")
if(pwd=='HOPE@123'):
    print("your password id correct")
else:
    print("Incorrect Passowrd")
# Out:
# Enter your password test@1234
# Incorrect Passowrd

# %%
# Catagory the people by their age like children, adult, citizen, senior citizen..

# %%
age=int(input("Enter your age:"))
if(age<18):
    print("Children")
elif(age>18 and age<40):
    print("Adult")
elif(age>40 and age<69):
    print("Citizen")
else:
    print("Senior citizen")
# Out:
# Enter your age: 20
# Adult

# %%
age=int(input("Enter your age:"))
if(age<=18):
    print("Children")
elif(age>18 and age<40):
    print("Adult")
elif(age>40 and age<69):
    print("Citizen")
else:
    print("Senior citizen")
# Out:
# Enter your age: 18
# Children

# %%
age=int(input("Enter your age:"))
if(age<=18):
    print("Children")
elif(age>18 and age<40):
    print("Adult")
elif(age>40 and age<69):
    print("Citizen")
else:
     print("Senior citizen")
# Out:
# Enter your age: 80
# Senior citizen

# %%
age=int(input("Enter your age:"))
if(age<=18):
    print("Children")
elif(age>18 and age<40):
    print("Adult")
elif(age>40 and age<69):
    print("Citizen")
else:
    print("Senior citizen")
# Out:
# Enter your age: 43
# Citizen

# %%
 # Find whether given number is positive or negative

# %%
value=int(input("Enter any number:"))
if(value>0):
    print("No is Positive:",value)
else:
    print("No is Negative:",value)
# Out:
# Enter any number: -1
# No is Negative: -1

# %%
value=int(input("Enter any number:"))
if(value>0):
    print("No is Positive:",value)
else:
    print("No is Negative:",value)
# Out:
# Enter any number: 1
# No is Positive: 1

# %%
# Check whether the given number is divisible by 5

# %%
num1=int(input("Enter a number to check:"))
if(num1%5==0):
    print("No is divisible by 5:",num1)
else:
    print("No is not divisible by 5:",num1)
# Out:
# Enter a number to check: 22
# No is not divisible by 5: 22

# %%
um1=int(input("Enter a number to check:"))
if(num1%5==0):
    print("No is divisible by 5:",num1)
else:
    print("No is not divisible by 5:",num1)
# Out:
# Enter a number to check: 25
# No is not divisible by 5: 22
